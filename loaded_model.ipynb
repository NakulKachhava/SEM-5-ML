# %%
import joblib

# %%
loaded_model = joblib.load("iris_decision_tree.pkl")

# %%
prediction = loaded_model.predict([[5.9, 3.0, 5.1, 1.8]])

#Ignore the warning below
# Out:
# C:\Users\student\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
prediction[0]
# Out:
# np.int64(2)

# %%
flowers = {
    0: "setosa",
    1: "versicolor",
    2: "virginica"
}

# %%
flowers[prediction[0]]
# Out:
# 'virginica'
